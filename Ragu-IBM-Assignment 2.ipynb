# %%
#preprocessing the dataset
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
d=pd.read_csv("C:\\Users\\ELCOT\\Documents\\house price data set.csv")

# %%
d.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
df=d.dropna()

# %%
d.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
x=pd.DataFrame(d.iloc[:,2:22].values)
y=d.iloc[:,22].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
#Build the ANN model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
classifier=Sequential()

# %%
#input layer,2 hidden layer,output layer
classifier.add(Dense(17,activation='relu'))
classifier.add(Dense(11,activation='relu'))
classifier.add(Dense(31,activation='relu'))
classifier.add(Dense(3,activation='linear'))

# %%
classifier.compile(optimizer='adam',loss='mse',metrics=['mse'])

# %%
#Train the model
classifier.fit(x_train,y_train,batch_size=10,epochs=25)
# Out:
# Epoch 1/25
# 1170/1170 [==============================] - 17s 7ms/step - loss: 374451273728.0000 - mse: 374451273728.0000
# Epoch 2/25
# 1170/1170 [==============================] - 10s 9ms/step - loss: 95547645952.0000 - mse: 95547645952.0000
# Epoch 3/25
# 1170/1170 [==============================] - 8s 7ms/step - loss: 60480880640.0000 - mse: 60480880640.0000
# Epoch 4/25
# 1170/1170 [==============================] - 8s 7ms/step - loss: 52791476224.0000 - mse: 52791476224.0000
# Epoch 5/25
# 1170/1170 [==============================] - 8s 7ms/step - loss: 47052165120.0000 - mse: 47052165120.0000
# Epoch 6/25
# 1170/1170 [==============================] - 9s 7ms/step - loss: 42680553472.0000 - mse: 42680553472.0000
# Epoch 7/25
# 1170/1170 [==============================] - 10s 8ms/step - loss: 39635202048.0000 - mse: 39635202048.0000
# Epoch 8/25
# 1170/1170 [==============================] - 8s 7ms/step - loss: 37688307712.0000 - mse: 37688307712.0000
# Epoch 9/25
# ...

# %%
#Test the model
y_pred=classifier.predict(x_test)
y_pred=(y_pred>0.5)
# Out:
# 92/92 [==============================] - 3s 9ms/step
